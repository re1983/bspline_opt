# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal

# Define the mean and covariance matrix
mean = [0, 0]
cov = [[1, 0], [0, 1]]

# Create a grid of points
x, y = np.mgrid[-5:5:.01, -5:5:.01]
pos = np.empty(x.shape + (2,))
pos[:, :, 0] = x; pos[:, :, 1] = y

# Create the multivariate normal distribution
rv = multivariate_normal(mean, cov)

# Plot the distribution
fig = plt.figure()
ax = fig.add_subplot(111)
ax.grid(color='dimgrey', linestyle='--', linewidth=1)
ax.set_aspect('equal', 'box')
ax.contourf(x, y, rv.pdf(pos))
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal

# Define the mean and covariance matrix
mean = [0, 0]
cov = [[1, 0], [0, 1]]

# Create a grid of points
x, y = np.mgrid[-3:3:.01, -3:3:.01]
pos = np.empty(x.shape + (2,))
pos[:, :, 0] = x; pos[:, :, 1] = y

# Create the multivariate normal distribution
rv = multivariate_normal(mean, cov)

# Plot the distribution
fig = plt.figure()
ax = fig.add_subplot(111)
contour = ax.contourf(x, y, rv.pdf(pos))

# Add a colorbar
cbar = plt.colorbar(contour)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal

# Define the mean and covariance matrix
mean = [0, 0]
cov = [[1, 0], [0, 1]]

# Create a grid of points
x, y = np.mgrid[-3:3:.01, -3:3:.01]
pos = np.empty(x.shape + (2,))
pos[:, :, 0] = x; pos[:, :, 1] = y

# Create the multivariate normal distribution
rv = multivariate_normal(mean, cov)

# Plot the distribution
fig = plt.figure()
ax = fig.add_subplot(111)
gradient = ax.pcolormesh(x, y, rv.pdf(pos), shading='auto')

# Add a colorbar
cbar = plt.colorbar(gradient)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal

# Define the mean and covariance matrix
mean = [0, 0]
cov = [[1, 0.5], [0.5, 1]]

# Create a grid of points
x, y = np.mgrid[-3:3:.01, -3:3:.01]
pos = np.empty(x.shape + (2,))
pos[:, :, 0] = x; pos[:, :, 1] = y

# Create the multivariate normal distribution
rv = multivariate_normal(mean, cov)

# Calculate the eigenvectors and eigenvalues of the covariance matrix
w, v = np.linalg.eig(cov)

# Plot the distribution and eigenvectors
fig = plt.figure()
ax = fig.add_subplot(111)
gradient = ax.pcolormesh(x, y, rv.pdf(pos), shading='auto')
ax.arrow(0, 0, v[0][0], v[1][0], color='red', width=0.05)
ax.arrow(0, 0, v[0][1], v[1][1], color='blue', width=0.05)

# Add a colorbar
cbar = plt.colorbar(gradient)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal

# Define the mean and covariance matrix
mean = [0, 0]
cov = [[1, 0], [0, 1]]
cov = [[1, 0.5], [0.5, 1]]

# Create a grid of points
x, y = np.mgrid[-3:3:.01, -3:3:.01]
pos = np.empty(x.shape + (2,))
pos[:, :, 0] = x; pos[:, :, 1] = y

# Create the multivariate normal distribution
rv = multivariate_normal(mean, cov)

# Calculate the eigenvectors and eigenvalues of the covariance matrix
w, v = np.linalg.eig(cov)

# Plot the distribution and eigenvectors/eigenvalues
fig = plt.figure()
ax = fig.add_subplot(111)
gradient = ax.pcolormesh(x, y, rv.pdf(pos), shading='auto')
ax.arrow(0, 0, v[0][0]*w[0], v[1][0]*w[0], color='red', width=0.05)
ax.arrow(0, 0, v[0][1]*w[1], v[1][1]*w[1], color='blue', width=0.05)

# Add a colorbar
cbar = plt.colorbar(gradient)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal

# Define the mean and covariance matrix
mean = [0, 0]
cov = [[1, 0], [0, 1]]
cov = [[1, 0.5], [0.5, 1]]
# Create a grid of points
x, y = np.mgrid[-3:3:.01, -3:3:.01]
pos = np.empty(x.shape + (2,))
pos[:, :, 0] = x; pos[:, :, 1] = y

# Create the multivariate normal distribution
rv = multivariate_normal(mean, cov)

# Calculate the eigenvectors and eigenvalues of the covariance matrix
w, v = np.linalg.eig(cov)

# Plot the distribution and eigenvectors/eigenvalues with labels
fig = plt.figure()
ax = fig.add_subplot(111)
gradient = ax.pcolormesh(x, y, rv.pdf(pos), shading='auto')
ax.arrow(0, 0, v[0][0]*w[0], v[1][0]*w[0], color='red', width=0.05)
ax.arrow(0, 0, v[0][1]*w[1], v[1][1]*w[1], color='blue', width=0.05)
ax.text(v[0][0]*w[0], v[1][0]*w[0], 'eigenvector 1', color='red', fontsize=12)
ax.text(v[0][1]*w[1], v[1][1]*w[1], 'eigenvector 2', color='blue', fontsize=12)

# Add a colorbar
cbar = plt.colorbar(gradient)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal

# Define the mean and covariance matrix
mean = [0, 0]
cov = [[1, 0.5], [0.5, 1]]

# Create a grid of points
x, y = np.mgrid[-3:3:.01, -3:3:.01]
pos = np.empty(x.shape + (2,))
pos[:, :, 0] = x; pos[:, :, 1] = y

# Create the multivariate normal distribution
rv = multivariate_normal(mean, cov)

# Calculate the eigenvectors and eigenvalues of the covariance matrix
w, v = np.linalg.eig(cov)

# Plot the distribution and eigenvectors/eigenvalues with labels and ellipse
fig = plt.figure()
ax = fig.add_subplot(111)
gradient = ax.pcolormesh(x, y, rv.pdf(pos), shading='auto')
ax.arrow(0, 0, v[0][0]*w[0], v[1][0]*w[0], color='red', width=0.05)
ax.arrow(0, 0, v[0][1]*w[1], v[1][1]*w[1], color='blue', width=0.05)
ax.text(v[0][0]*w[0], v[1][0]*w[0], 'eigenvector 1', color='red', fontsize=12)
ax.text(v[0][1]*w[1], v[1][1]*w[1], 'eigenvector 2', color='blue', fontsize=12)

# Add a colorbar
cbar = plt.colorbar(gradient)

# Add an ellipse to the plot
ellipse = plt.Circle((mean[0], mean[1]), w[0], fill=False)
ax.add_artist(ellipse)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
from matplotlib.patches import Ellipse

# Define the mean and covariance matrix
mean = [0, 0]
cov = [[1, 0.5], [0.5, 1]]

# Create a grid of points
x, y = np.mgrid[-3:3:.01, -3:3:.01]
pos = np.empty(x.shape + (2,))
pos[:, :, 0] = x; pos[:, :, 1] = y

# Create the multivariate normal distribution
rv = multivariate_normal(mean, cov)

# Calculate the eigenvectors and eigenvalues of the covariance matrix
w, v = np.linalg.eig(cov)

# Plot the distribution and eigenvectors/eigenvalues with labels and ellipse
fig = plt.figure()
ax = fig.add_subplot(111)
gradient = ax.pcolormesh(x, y, rv.pdf(pos), shading='auto')
ax.arrow(mean[0], mean[1], v[0][0]*w[0], v[1][0]*w[0], color='red', width=0.05, length_includes_head=True)
ax.arrow(mean[0], mean[1], v[0][1]*w[1], v[1][1]*w[1], color='blue', width=0.05, length_includes_head=True)
ax.text(v[0][0]*w[0], v[1][0]*w[0], 'eigenvector 1', color='red', fontsize=12)
ax.text(v[0][1]*w[1], v[1][1]*w[1], 'eigenvector 2', color='blue', fontsize=12)

# Add a colorbar
cbar = plt.colorbar(gradient)

# Add an ellipse to the plot
ellipse = Ellipse((mean[0], mean[1]), w[0]*2, w[1]*2,
                  angle=np.rad2deg(np.arccos(v[0, 0])))

ax.add_artist(ellipse)
ellipse.set_clip_box(ax.bbox)
ellipse.set_edgecolor('black')
ellipse.set_facecolor('none')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
from matplotlib.patches import Ellipse

# Define the mean and covariance matrix
mean = [0, 0]
cov = [[1, 0.5], [0.5, 1]]

# Create a grid of points
x, y = np.mgrid[-3:3:.01, -3:3:.01]
pos = np.empty(x.shape + (2,))
pos[:, :, 0] = x; pos[:, :, 1] = y

# Create the multivariate normal distribution
rv = multivariate_normal(mean, cov)

# Calculate the eigenvectors and eigenvalues of the covariance matrix
w, v = np.linalg.eig(cov)

# Plot the distribution and eigenvectors/eigenvalues with labels and ellipse
fig = plt.figure()
ax = fig.add_subplot(111)
gradient = ax.pcolormesh(x, y, rv.pdf(pos), shading='auto')
ax.arrow(mean[0], mean[1], v[0][0]*w[0], v[1][0]*w[0], color='red', width=0.05, length_includes_head=True)
ax.arrow(mean[0], mean[1], v[0][1]*w[1], v[1][1]*w[1], color='blue', width=0.05, length_includes_head=True)
ax.text(v[0][0]*w[0], v[1][0]*w[0], '$e_1\sqrt{\lambda_1}$', color='red', fontsize=12)
ax.text(v[0][1]*w[1], v[1][1]*w[1], '$e_2\sqrt{\lambda_2}$', color='blue', fontsize=12)

# Add a colorbar
cbar = plt.colorbar(gradient)

# Add an ellipse to the plot
ellipse = Ellipse((mean[0], mean[1]), w[0]*2, w[1]*2,
                  angle=np.rad2deg(np.arccos(v[0, 0])))

ax.add_artist(ellipse)
ellipse.set_clip_box(ax.bbox)
ellipse.set_edgecolor('black')
ellipse.set_facecolor('none')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
from matplotlib.patches import Ellipse

# Define the mean and covariance matrix
mean = [0, 0]
cov = [[1, 0.5], [0.5, 1]]

# Create a grid of points
x, y = np.mgrid[-3:3:.01, -3:3:.01]
pos = np.empty(x.shape + (2,))
pos[:, :, 0] = x; pos[:, :, 1] = y

# Create the multivariate normal distribution
rv = multivariate_normal(mean, cov)

# Calculate the eigenvectors and eigenvalues of the covariance matrix
w, v = np.linalg.eig(cov)

# Plot the distribution and eigenvectors/eigenvalues with labels and ellipse
fig = plt.figure()
ax = fig.add_subplot(111)
gradient = ax.pcolormesh(x, y, rv.pdf(pos), shading='auto', cmap='viridis')
gradient = ax.pcolormesh(x, y, rv.pdf(pos), shading='auto', cmap='jet')
ax.arrow(mean[0], mean[1], v[0][0]*w[0], v[1][0]*w[0], color='red', width=0.05, length_includes_head=True)
ax.arrow(mean[0], mean[1], v[0][1]*w[1], v[1][1]*w[1], color='blue', width=0.05, length_includes_head=True)
ax.text(v[0][0]*w[0], v[1][0]*w[0], '$e_1\sqrt{\lambda_1}$', color='red', fontsize=12)
ax.text(v[0][1]*w[1]*1.1, v[1][1]*w[1]*1.1, '$e_2\sqrt{\lambda_2}$', color='blue', fontsize=12)

# Add a colorbar
cbar = plt.colorbar(gradient)

# Add an ellipse to the plot
ellipse = Ellipse((mean[0], mean[1]), w[0]*2, w[1]*2,
                  angle=np.rad2deg(np.arccos(v[0, 0])))
ax.add_artist(ellipse)
ellipse.set_clip_box(ax.bbox)
ellipse.set_edgecolor('black')
ellipse.set_facecolor('none')
ellipse.set_linestyle('dashed')
ellipse.set_linewidth(2)

plt.show()
